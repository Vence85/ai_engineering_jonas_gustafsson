# %%
import lancedb

db = lancedb.connect(uri="vector_database")
db
# Out:
# LanceDBConnection(uri='c:\\Skolprojekt\\ai_engineering\\ai_engineering_jonas_gustafsson\\exercises\\exercise_lancedb\\vector_database')

# %%
from pathlib import Path
stories = []

# %%
for path in Path("data").glob(*"txt"):
    stories.append({
        "id":path.stem,
        "text": path.read_text(encoding="utf-8"),
        "source": path.name
    })    

stories
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for path in Path("data").glob(*"txt"):
#       2     stories.append({
#       3         "id":path.stem,
#       4         "text": path.read_text(encoding="utf-8"),
#       5         "source": path.name
#       6     })
#       8 stories
#
# TypeError: Path.glob() takes 2 positional arguments but 4 were given
